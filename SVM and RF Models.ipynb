# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("Model_Correct_New.csv")
df1.head()
# Out:
#                Date   Time  Cooling Devices  Indoor Temperature(C)  \
# 0  2021-07-25 12:00  12:00              1.5                   31.9
# 1  2021-07-25 12:30  12:30              1.5                   32.1
# 2  2021-07-25 13:00  13:00              2.5                   32.3
# 3  2021-07-25 13:30  13:30              1.0                   32.6
# 4  2021-07-25 14:00  14:00              1.0                   32.6
#
#    Indoor Humidity(%)  Outdoor Temperature(C)  Outdoor Humidity(%)  \
# 0                  67                    34.6                   59
# 1                  65                    34.9                   58
# 2                  66                    35.4                   62
# 3                  70                    34.0                   73
# 4                  72                    33.6                   73
#
#    Dew Point(C)  Feels Like (C)  Wind(km/h)  ...  REL Pressure(inhg)  \
# 0          25.5            43.4         1.1  ...               29.76
# ...

# %%
df2 = df1.set_index('Date')
df2.head()
# Out:
#                    Time  Cooling Devices  Indoor Temperature(C)  \
# Date
# 2021-07-25 12:00  12:00              1.5                   31.9
# 2021-07-25 12:30  12:30              1.5                   32.1
# 2021-07-25 13:00  13:00              2.5                   32.3
# 2021-07-25 13:30  13:30              1.0                   32.6
# 2021-07-25 14:00  14:00              1.0                   32.6
#
#                   Indoor Humidity(%)  Outdoor Temperature(C)  \
# Date
# 2021-07-25 12:00                  67                    34.6
# 2021-07-25 12:30                  65                    34.9
# 2021-07-25 13:00                  66                    35.4
# 2021-07-25 13:30                  70                    34.0
# 2021-07-25 14:00                  72                    33.6
#
#                   Outdoor Humidity(%)  Dew Point(C)  Feels Like (C)  \
# Date
# 2021-07-25 12:00                   59          25.5            43.4
# ...

# %%
dumies_1 = pd.get_dummies(df2.Time)
dumies_1.head()
# Out:
#                   10:00  10:30  11:00  11:30  12:00  12:30  13:00  13:30  \
# Date
# 2021-07-25 12:00      0      0      0      0      1      0      0      0
# 2021-07-25 12:30      0      0      0      0      0      1      0      0
# 2021-07-25 13:00      0      0      0      0      0      0      1      0
# 2021-07-25 13:30      0      0      0      0      0      0      0      1
# 2021-07-25 14:00      0      0      0      0      0      0      0      0
#
#                   14:00  14:30  ...  22:30  23:00  23:30  6:30  7:00  7:30  \
# Date                            ...
# 2021-07-25 12:00      0      0  ...      0      0      0     0     0     0
# 2021-07-25 12:30      0      0  ...      0      0      0     0     0     0
# 2021-07-25 13:00      0      0  ...      0      0      0     0     0     0
# 2021-07-25 13:30      0      0  ...      0      0      0     0     0     0
# 2021-07-25 14:00      1      0  ...      0      0      0     0     0     0
#
# ...

# %%
dumies_2 = pd.get_dummies(df2.Pattern)
dumies_2.head()
# Out:
#                   friday  monday  saturday  sunday  thursday  tuesday  \
# Date
# 2021-07-25 12:00       0       0         0       1         0        0
# 2021-07-25 12:30       0       0         0       1         0        0
# 2021-07-25 13:00       0       0         0       1         0        0
# 2021-07-25 13:30       0       0         0       1         0        0
# 2021-07-25 14:00       0       0         0       1         0        0
#
#                   wednesday
# Date
# 2021-07-25 12:00          0
# 2021-07-25 12:30          0
# 2021-07-25 13:00          0
# 2021-07-25 13:30          0
# 2021-07-25 14:00          0

# %%
df3 = pd.concat([df2, pd.get_dummies(df2['Pattern'])], axis=1)
df3.head()
# Out:
#                    Time  Cooling Devices  Indoor Temperature(C)  \
# Date
# 2021-07-25 12:00  12:00              1.5                   31.9
# 2021-07-25 12:30  12:30              1.5                   32.1
# 2021-07-25 13:00  13:00              2.5                   32.3
# 2021-07-25 13:30  13:30              1.0                   32.6
# 2021-07-25 14:00  14:00              1.0                   32.6
#
#                   Indoor Humidity(%)  Outdoor Temperature(C)  \
# Date
# 2021-07-25 12:00                  67                    34.6
# 2021-07-25 12:30                  65                    34.9
# 2021-07-25 13:00                  66                    35.4
# 2021-07-25 13:30                  70                    34.0
# 2021-07-25 14:00                  72                    33.6
#
#                   Outdoor Humidity(%)  Dew Point(C)  Feels Like (C)  \
# Date
# 2021-07-25 12:00                   59          25.5            43.4
# ...

# %%
df5 = df3.drop(['Time','Pattern'],axis='columns') # Without Time Slots
df5.head()
# Out:
#                   Cooling Devices  Indoor Temperature(C)  Indoor Humidity(%)  \
# Date
# 2021-07-25 12:00              1.5                   31.9                  67
# 2021-07-25 12:30              1.5                   32.1                  65
# 2021-07-25 13:00              2.5                   32.3                  66
# 2021-07-25 13:30              1.0                   32.6                  70
# 2021-07-25 14:00              1.0                   32.6                  72
#
#                   Outdoor Temperature(C)  Outdoor Humidity(%)  Dew Point(C)  \
# Date
# 2021-07-25 12:00                    34.6                   59          25.5
# 2021-07-25 12:30                    34.9                   58          25.4
# 2021-07-25 13:00                    35.4                   62          27.0
# 2021-07-25 13:30                    34.0                   73          28.5
# 2021-07-25 14:00                    33.6                   73          28.1
#
# ...

# %%
df6 = df3.drop(['Time','Pattern','Indoor Temperature(C)','Indoor Humidity(%)','Dew Point(C)','Feels Like (C)','Wind(km/h)','Gust(km/h)','Wind Direction(deg)','ABS Pressure(inhg)','REL Pressure(inhg)','Solar Rad.(w/m2)','UVI','Hourly Rain(mm)','Event Rain(mm)','Daily Rain(mm)','Weekly Rain(mm)','Monthly Rain(mm)','Yearly Rain(mm)'],axis='columns') # Without Time Slots
df6.head() #Without Time
# Out:
#                   Cooling Devices  Outdoor Temperature(C)  \
# Date
# 2021-07-25 12:00              1.5                    34.6
# 2021-07-25 12:30              1.5                    34.9
# 2021-07-25 13:00              2.5                    35.4
# 2021-07-25 13:30              1.0                    34.0
# 2021-07-25 14:00              1.0                    33.6
#
#                   Outdoor Humidity(%)  friday  monday  saturday  sunday  \
# Date
# 2021-07-25 12:00                   59       0       0         0       1
# 2021-07-25 12:30                   58       0       0         0       1
# 2021-07-25 13:00                   62       0       0         0       1
# 2021-07-25 13:30                   73       0       0         0       1
# 2021-07-25 14:00                   73       0       0         0       1
#
#                   thursday  tuesday  wednesday
# Date
# 2021-07-25 12:00         0        0          0
# 2021-07-25 12:30         0        0          0
# ...

# %%
df4 = pd.concat([df3, pd.get_dummies(df2['Time'])], axis=1)
df4.head()
# Out:
#                    Time  Cooling Devices  Indoor Temperature(C)  \
# Date
# 2021-07-25 12:00  12:00              1.5                   31.9
# 2021-07-25 12:30  12:30              1.5                   32.1
# 2021-07-25 13:00  13:00              2.5                   32.3
# 2021-07-25 13:30  13:30              1.0                   32.6
# 2021-07-25 14:00  14:00              1.0                   32.6
#
#                   Indoor Humidity(%)  Outdoor Temperature(C)  \
# Date
# 2021-07-25 12:00                  67                    34.6
# 2021-07-25 12:30                  65                    34.9
# 2021-07-25 13:00                  66                    35.4
# 2021-07-25 13:30                  70                    34.0
# 2021-07-25 14:00                  72                    33.6
#
#                   Outdoor Humidity(%)  Dew Point(C)  Feels Like (C)  \
# Date
# 2021-07-25 12:00                   59          25.5            43.4
# ...

# %%
df = df4.drop(['Time','Pattern'],axis='columns') # With Time Slots
df.head()
# Out:
#                   Cooling Devices  Indoor Temperature(C)  Indoor Humidity(%)  \
# Date
# 2021-07-25 12:00              1.5                   31.9                  67
# 2021-07-25 12:30              1.5                   32.1                  65
# 2021-07-25 13:00              2.5                   32.3                  66
# 2021-07-25 13:30              1.0                   32.6                  70
# 2021-07-25 14:00              1.0                   32.6                  72
#
#                   Outdoor Temperature(C)  Outdoor Humidity(%)  Dew Point(C)  \
# Date
# 2021-07-25 12:00                    34.6                   59          25.5
# 2021-07-25 12:30                    34.9                   58          25.4
# 2021-07-25 13:00                    35.4                   62          27.0
# 2021-07-25 13:30                    34.0                   73          28.5
# 2021-07-25 14:00                    33.6                   73          28.1
#
# ...

# %%
df.shape
# Out:
# (454, 62)

# %%
df.describe()
# Out:
#        Cooling Devices  Indoor Temperature(C)  Indoor Humidity(%)  \
# count       454.000000             454.000000          454.000000
# mean          1.659692              31.203304           72.638767
# std           0.984059               0.844702            3.233639
# min           0.000000              28.700000           57.000000
# 25%           1.000000              30.700000           71.000000
# 50%           1.500000              31.200000           73.000000
# 75%           2.500000              31.700000           75.000000
# max           5.500000              33.500000           81.000000
#
#        Outdoor Temperature(C)  Outdoor Humidity(%)  Dew Point(C)  \
# count              454.000000           454.000000    454.000000
# mean                31.527753            75.174009     26.508370
# std                  1.812570             8.164594      1.184175
# min                 25.700000            49.000000     21.900000
# ...

# %%
df.isna().sum()
# Out:
# Cooling Devices           0
# Indoor Temperature(C)     0
# Indoor Humidity(%)        0
# Outdoor Temperature(C)    0
# Outdoor Humidity(%)       0
#                          ..
# 7:30                      0
# 8:00                      0
# 8:30                      0
# 9:00                      0
# 9:30                      0
# Length: 62, dtype: int64

# %%
import seaborn as sns

# %%
plt.figure(figsize = (16,6))
sns.heatmap(df6.corr(), annot = True, linewidths = 1, fmt = ".2g", cmap = 'coolwarm')
plt.xticks(rotation = 'horizontal')
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5, 8.5, 9.5]),
#  [Text(0.5, 0, 'Cooling Devices'),
#   Text(1.5, 0, 'Outdoor Temperature(C)'),
#   Text(2.5, 0, 'Outdoor Humidity(%)'),
#   Text(3.5, 0, 'friday'),
#   Text(4.5, 0, 'monday'),
#   Text(5.5, 0, 'saturday'),
#   Text(6.5, 0, 'sunday'),
#   Text(7.5, 0, 'thursday'),
#   Text(8.5, 0, 'tuesday'),
#   Text(9.5, 0, 'wednesday')])

# %%
y = df['Cooling Devices']  
x1 = df['Outdoor Temperature(C)']  
x2 = df['Outdoor Humidity(%)']

# %%
fig,ax = plt.subplots(figsize = (24,8))
ax.plot(df.index,y, color="red", marker="o")
ax.set_ylabel("Load in MW")
ax.set_xlabel("Date")
ax2 = ax.twinx()
ax3 = ax.twinx()
ax2.plot(df.index,x1, color="blue", marker="o")
ax2.set_ylabel("Temperature")
ax3.plot(df.index,x2, color="green", marker="o")
ax3.set_ylabel("Humidity")
ax3.spines["right"].set_position(("axes",1.05))
fig.legend(["Cooling Devices Consumption","Outdoor Temperature(C)","Outdoor Humidity(%)"], loc = "upper right")
fig.show()
# Out:
# C:\Users\Sudeera\AppData\Local\Temp\ipykernel_7520\1735688534.py:13: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
df['Cooling Devices'] = df['Cooling Devices'] / 5.5
df
# Out:
#                   Cooling Devices  Indoor Temperature(C)  Indoor Humidity(%)  \
# Date
# 2021-07-25 12:00         0.272727                   31.9                  67
# 2021-07-25 12:30         0.272727                   32.1                  65
# 2021-07-25 13:00         0.454545                   32.3                  66
# 2021-07-25 13:30         0.181818                   32.6                  70
# 2021-07-25 14:00         0.181818                   32.6                  72
# ...                           ...                    ...                 ...
# 2021-09-17 16:00         0.181818                   31.8                  75
# 2021-09-17 16:30         0.181818                   31.6                  76
# 2021-09-17 17:00         0.181818                   31.5                  76
# 2021-09-17 17:30         0.090909                   31.4                  73
# 2021-09-17 18:00         0.090909                   31.3                  71
#
# ...

# %%
df7 = df.drop(['Cooling Devices'],axis='columns')
df7
# Out:
#                   Indoor Temperature(C)  Indoor Humidity(%)  \
# Date
# 2021-07-25 12:00                   31.9                  67
# 2021-07-25 12:30                   32.1                  65
# 2021-07-25 13:00                   32.3                  66
# 2021-07-25 13:30                   32.6                  70
# 2021-07-25 14:00                   32.6                  72
# ...                                 ...                 ...
# 2021-09-17 16:00                   31.8                  75
# 2021-09-17 16:30                   31.6                  76
# 2021-09-17 17:00                   31.5                  76
# 2021-09-17 17:30                   31.4                  73
# 2021-09-17 18:00                   31.3                  71
#
#                   Outdoor Temperature(C)  Outdoor Humidity(%)  Dew Point(C)  \
# Date
# 2021-07-25 12:00                    34.6                   59          25.5
# 2021-07-25 12:30                    34.9                   58          25.4
# ...

# %%
X_cols = df.drop(['Cooling Devices','Indoor Temperature(C)','Indoor Humidity(%)','Dew Point(C)','Feels Like (C)','Wind(km/h)','Gust(km/h)','Wind Direction(deg)','ABS Pressure(inhg)','REL Pressure(inhg)','Solar Rad.(w/m2)','UVI','Hourly Rain(mm)','Event Rain(mm)','Daily Rain(mm)','Weekly Rain(mm)','Monthly Rain(mm)','Yearly Rain(mm)'],axis='columns')
x = X_cols.values   #Should change with dataframe (df5 or df)
x
# Out:
# array([[34.6, 59. ,  0. , ...,  0. ,  0. ,  0. ],
#        [34.9, 58. ,  0. , ...,  0. ,  0. ,  0. ],
#        [35.4, 62. ,  0. , ...,  0. ,  0. ,  0. ],
#        ...,
#        [30.3, 81. ,  1. , ...,  0. ,  0. ,  0. ],
#        [30.8, 71. ,  1. , ...,  0. ,  0. ,  0. ],
#        [30.4, 72. ,  1. , ...,  0. ,  0. ,  0. ]])

# %%
Y_cols = 'Cooling Devices'
y = df[Y_cols].values   #Should change with dataframe (df5 or df)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=30)
y_train
# Out:
# array([0.63636364, 0.18181818, 0.18181818, 0.18181818, 0.54545455,
#        0.36363636, 0.45454545, 0.27272727, 0.27272727, 0.72727273,
#        0.36363636, 0.27272727, 0.27272727, 0.09090909, 0.45454545,
#        0.27272727, 0.27272727, 0.        , 0.45454545, 0.36363636,
#        0.09090909, 0.18181818, 0.09090909, 0.18181818, 0.36363636,
#        0.18181818, 0.09090909, 0.54545455, 0.36363636, 0.54545455,
#        0.45454545, 0.36363636, 0.45454545, 0.27272727, 0.27272727,
#        0.18181818, 0.        , 0.09090909, 0.54545455, 0.45454545,
#        0.        , 0.45454545, 0.36363636, 0.09090909, 0.18181818,
#        0.36363636, 0.27272727, 0.54545455, 0.45454545, 0.45454545,
#        1.        , 0.45454545, 0.27272727, 0.45454545, 0.        ,
#        0.54545455, 0.36363636, 0.54545455, 0.18181818, 0.18181818,
#        0.54545455, 0.27272727, 0.09090909, 0.18181818, 0.        ,
#        0.45454545, 0.54545455, 0.27272727, 0.36363636, 0.18181818,
# ...

# %%
y_train = y_train.ravel()
y_train
# Out:
# array([0.63636364, 0.18181818, 0.18181818, 0.18181818, 0.54545455,
#        0.36363636, 0.45454545, 0.27272727, 0.27272727, 0.72727273,
#        0.36363636, 0.27272727, 0.27272727, 0.09090909, 0.45454545,
#        0.27272727, 0.27272727, 0.        , 0.45454545, 0.36363636,
#        0.09090909, 0.18181818, 0.09090909, 0.18181818, 0.36363636,
#        0.18181818, 0.09090909, 0.54545455, 0.36363636, 0.54545455,
#        0.45454545, 0.36363636, 0.45454545, 0.27272727, 0.27272727,
#        0.18181818, 0.        , 0.09090909, 0.54545455, 0.45454545,
#        0.        , 0.45454545, 0.36363636, 0.09090909, 0.18181818,
#        0.36363636, 0.27272727, 0.54545455, 0.45454545, 0.45454545,
#        1.        , 0.45454545, 0.27272727, 0.45454545, 0.        ,
#        0.54545455, 0.36363636, 0.54545455, 0.18181818, 0.18181818,
#        0.54545455, 0.27272727, 0.09090909, 0.18181818, 0.        ,
#        0.45454545, 0.54545455, 0.27272727, 0.36363636, 0.18181818,
# ...

# %%
y_test = y_test.ravel()
y_test
# Out:
# array([0.54545455, 0.36363636, 0.54545455, 0.36363636, 0.45454545,
#        0.        , 0.27272727, 0.54545455, 0.54545455, 0.18181818,
#        0.45454545, 0.45454545, 0.45454545, 0.18181818, 0.45454545,
#        0.36363636, 0.54545455, 0.        , 0.36363636, 0.45454545,
#        0.18181818, 0.36363636, 0.45454545, 0.09090909, 0.18181818,
#        0.09090909, 0.36363636, 0.        , 0.45454545, 0.36363636,
#        0.27272727, 0.63636364, 0.63636364, 0.54545455, 0.27272727,
#        0.36363636, 0.09090909, 0.63636364, 0.27272727, 0.        ,
#        0.27272727, 0.18181818, 0.18181818, 0.27272727, 0.09090909,
#        0.72727273])

# %%
from sklearn.svm import SVR
SVReg = SVR(kernel = 'rbf', C = 700, epsilon = 0.003, gamma = 0.0001) # C = 700, epsilon = 0.003, gamma = 0.0001)  C = 2000, epsilon = 0.0001, gamma = 0.0001)  C = 20, epsilon = 0.005, gamma = 0.01) C = 10, epsilon = 0.001, gamma = 0.001) , C = 1, epsilon = 0.69, gamma = 1) #regr = SVR(kernel = 'rbf', C = 10, epsilon = 0.03, gamma = 7.75),(C = 1, epsilon = 0.69, gamma = 1)
SVReg.fit(x_train,y_train)
# Out:
# SVR(C=700, epsilon=0.003, gamma=0.0001)

# %%
Predicted_train = SVReg.predict(x_train)
Predicted_train
# Out:
# array([ 5.26675356e-01,  1.44219895e-01,  2.34322073e-01,  1.91863616e-01,
#         3.42168029e-01,  3.36630972e-01,  4.52417302e-01,  3.18665775e-01,
#         2.84984900e-01,  5.24698179e-01,  3.22890113e-01,  3.24663338e-01,
#         3.38174682e-01,  3.77565977e-01,  4.47650108e-01,  2.75398979e-01,
#         3.32255048e-01,  3.34157717e-01,  4.33552606e-01,  2.56507587e-01,
#         3.45697655e-01,  1.78184011e-01,  2.76678393e-01,  2.42015101e-01,
#         3.56095331e-01,  2.46296052e-01,  2.15896688e-01,  4.52916024e-01,
#         2.86526706e-01,  3.12871870e-01,  3.10358116e-01,  2.64677760e-01,
#         3.47672281e-01,  2.94732548e-01,  2.69578554e-01,  1.78405062e-01,
#         3.03251873e-01,  1.42186059e-01,  3.24376435e-01,  3.28485430e-01,
#         3.13077594e-01,  3.19265317e-01,  4.29034004e-01,  2.24102704e-01,
#         2.09975115e-01,  1.90269750e-01,  9.18827873e-02,  5.08983790e-01,
# ...

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
print(r2_score(y_train,Predicted_train)*100)
print(mean_squared_error(y_train,Predicted_train))
print(mean_absolute_error(y_train,Predicted_train))
print(mean_absolute_percentage_error(y_train,Predicted_train))
rmse = np.sqrt(mean_squared_error(y_train,Predicted_train))
print(rmse)
cvrmse = (np.sqrt(mean_squared_error(y_train, Predicted_train)))/(np.mean(y_train))
print(cvrmse)
# CVRSME = 100 * ((sum((test_labels - predictions)**2) / (pd.Series(test_labels).count()-1))**(0.5)) / np.mean(test_labels)
# Out:
# 33.45271435380537
# 0.020829792447935258
# 0.10737166891545286
# 68607083935787.81
# 0.14432530078934622
# 0.4848293038492409

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler

SC1 = StandardScaler()
SC2 = MinMaxScaler()
SC3 = RobustScaler()

# %%
x1 = SC1.fit_transform(df7)  #Should change with dataframe (df5 or df)
x2 = SC2.fit_transform(df7)  #Should change with dataframe (df5 or df)
x3 = SC3.fit_transform(df7)  #Should change with dataframe (df5 or df)

#y1 = SC1.fit_transform(y)  #Should change with dataframe (df5 or df)
#y2 = SC2.fit_transform(y)  #Should change with dataframe (df5 or df)
#y3 = SC3.fit_transform(y)  #Should change with dataframe (df5 or df)

# %%
x_train, x_test, y_train, y_test = train_test_split(x2, y, test_size=0.1, random_state=30)
y_train = y_train.ravel()
y_test = y_test.ravel()
regr = SVR(kernel = 'rbf', C = 700, epsilon = 0.003, gamma = 0.0001)#, C = 1, epsilon = 0.69, gamma = 1) #regr = SVR(kernel = 'rbf', C = 10, epsilon = 0.03, gamma = 7.75)
regr.fit(x_train,y_train)
predict_train =  regr.predict(x_train)
print(r2_score(y_train,predict_train)*100)
print(mean_squared_error(y_train,predict_train))
print(mean_absolute_error(y_train,predict_train))
print(mean_absolute_percentage_error(y_train,predict_train))
rmse = np.sqrt(mean_squared_error(y_train,predict_train))
print(rmse)
cvrmse = (np.sqrt(mean_squared_error(y_train, predict_train)))/(np.mean(y_train))
print(cvrmse)
# Out:
# 38.04105840366796
# 0.019393606834798658
# 0.10310356291711081
# 64385792654586.42
# 0.13926093075517862
# 0.4678166596027258

# %%
x_train, x_test, y_train, y_test = train_test_split(x3, y, test_size=0.1, random_state=30)
y_train = y_train.ravel()
y_test = y_test.ravel()
regr = SVR(kernel = 'rbf', C = 700, epsilon = 0.003, gamma = 0.0001)#, C = 1, epsilon = 0.69, gamma = 1) #regr = SVR(kernel = 'rbf', C = 10, epsilon = 0.03, gamma = 7.75)
regr.fit(x_train,y_train)
predict_train =  regr.predict(x_train)
print(r2_score(y_train,predict_train)*100)
print(mean_squared_error(y_train,predict_train))
print(mean_absolute_error(y_train,predict_train))
print(mean_absolute_percentage_error(y_train,predict_train))
rmse = np.sqrt(mean_squared_error(y_train,predict_train))
print(rmse)
cvrmse = (np.sqrt(mean_squared_error(y_train, predict_train)))/(np.mean(y_train))
print(cvrmse)
# Out:
# 40.037827792668125
# 0.01876860325222741
# 0.10014687820306001
# 64981389672523.664
# 0.1369985520077764
# 0.46021669267282966

# %%
x_train, x_test, y_train, y_test = train_test_split(x1, y, test_size=0.1, random_state=30)
y_train = y_train.ravel()
y_test = y_test.ravel()
regr = SVR(kernel = 'rbf', C = 700, epsilon = 0.003, gamma = 0.0001)#, C = 1, epsilon = 0.69, gamma = 1) #regr = SVR(kernel = 'rbf', C = 10, epsilon = 0.03, gamma = 7.75)
regr.fit(x_train,y_train)
predict_train =  regr.predict(x_train)
print(r2_score(y_train,predict_train)*100)
print(mean_squared_error(y_train,predict_train))
print(mean_absolute_error(y_train,predict_train))
print(mean_absolute_percentage_error(y_train,predict_train))
rmse = np.sqrt(mean_squared_error(y_train,predict_train))
print(rmse)
cvrmse = (np.sqrt(mean_squared_error(y_train, predict_train)))/(np.mean(y_train))
print(cvrmse)
# Out:
# 58.93272945183541
# 0.012854359326831365
# 0.07772254772871057
# 52799723543783.34
# 0.11337706702341248
# 0.3808654766475114

# %%
plt.figure(figsize = (16,4))
plt.plot(y_train, color = 'b', label = "Original Data")
plt.plot(predict_train, color = 'y', label = "SVReg Predicted Data")
plt.legend(loc = 'best')
plt.xlabel('Time')
plt.ylabel('Load in MW')
plt.title('Original Training Data with SVM Predicted Data')

plt.show
plt.savefig("Training_Set.jpg")

# %%
regr.score(x_test,y_test)*100
# Out:
# 50.25544937664458

# %%
pred =  regr.predict(x_test)
print(r2_score(y_test,pred)*100)
print(mean_squared_error(y_test,pred))
print(mean_absolute_error(y_test,pred))
print(mean_absolute_percentage_error(y_test,pred))
rmse = np.sqrt(mean_squared_error(y_test,pred))
print(rmse)
cvrmse = (np.sqrt(mean_squared_error(y_test, pred)))/(np.mean(y_test))
print(cvrmse)
# Out:
# 50.25544937664458
# 0.017992949558768866
# 0.11093470838411766
# 71604477089000.66
# 0.13413780063341155
# 0.39692238082167397

# %%
plt.figure(figsize = (16,4))
plt.plot(y_test, label = "Original")
plt.plot(pred, label = "Predicted")
plt.legend(loc = 'best')
plt.xlabel('Time')
plt.ylabel('Load in MW')
plt.title('Original Test Data with SVM Predicted Data')

plt.show
plt.savefig("Test_Set_SVM.jpg")

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
RFReg = RandomForestRegressor(n_estimators = 120, max_depth = 30, n_jobs = -1, bootstrap = True, oob_score = True, 
                              random_state = 40)
x_train2, x_test2, y_train2, y_test2 = train_test_split( x1, y, test_size=0.2, random_state=30, shuffle = "False")
y_train2 = y_train2.ravel()
y_test2 = y_test2.ravel()
RFReg.fit(x_train2,y_train2)
predicted_train2 =  RFReg.predict(x_train2)
print(r2_score(y_train2,predicted_train2)*100)
print(mean_squared_error(y_train2,predicted_train2))
print(mean_absolute_error(y_train2,predicted_train2))
print(mean_absolute_percentage_error(y_train2,predicted_train2))
rmse = np.sqrt(mean_squared_error(y_train2,predicted_train2))
print(rmse)
cvrmse = (np.sqrt(mean_squared_error(y_train2, predicted_train2)))/(np.mean(y_train2))
print(cvrmse)
# Out:
# 91.6465187066602
# 0.0026207447629310967
# 0.040829785457884724
# 28647991619136.28
# 0.051193210125280254
# 0.1720660673655253

# %%
plt.figure(figsize = (16,4))
plt.plot(y_train2, color = 'b', label = "Original Data")
plt.plot(predicted_train2, color = 'y', label = "RFReg Predicted Data")
plt.legend(loc = 'best')
plt.xlabel('Time')
plt.ylabel('Load in MW')
# Out:
# Text(0, 0.5, 'Load in MW')

# %%
pred2 =  RFReg.predict(x_test2)
print(r2_score(y_test2,pred2)*100)
print(mean_squared_error(y_test2,pred2))
print(mean_absolute_error(y_test2,pred2))
print(mean_absolute_percentage_error(y_test2,pred2))
rmse = np.sqrt(mean_squared_error(y_test2,pred2))
print(rmse)
cvrmse = (np.sqrt(mean_squared_error(y_test2, pred2)))/(np.mean(y_test2))
print(cvrmse)
# Out:
# 59.08103830909328
# 0.01385199396563033
# 0.09343989343989345
# 68123880477291.32
# 0.11769449420270402
# 0.3693172059464161

# %%
RFReg.score(x_test2,y_test2)*100
# Out:
# 59.08103830909328

# %%
plt.figure(figsize = (16,4))
plt.plot(y_test2, label = "Original")
plt.plot(pred2, label = "Predicted")
plt.legend(loc = 'best')
plt.xlabel('Time')
plt.ylabel('Load in MW')
plt.title('Original Test Data with RF Predicted Data')

plt.show
plt.savefig("Test_Set_RF.jpg")

# %%
#get the importance of the resulting features
importances = RFReg.feature_importances_
#create the data frame for visualization
final_df = pd.DataFrame({"Features": df7.columns, "Importances": importances})
final_df.set_index("Importances")

#sort in ascending order to  better visualization
final_df = final_df.sort_values('Importances')


#plot the feature in bare
plt.figure(figsize=(24,10))
plt.xticks(rotation= 45)
sns.barplot(x="Features",y="Importances", data=final_df)
# Out:
# <AxesSubplot:xlabel='Features', ylabel='Importances'>

# %%
#feature_names = print(df7.columns)
#feature_names

# %%
#RFReg.feature_importances_

# %%
#pd.set_option('display.max_rows', 100)

# %%
#feature_importances = pd.DataFrame(RFReg.feature_importances_, index = df7.columns, columns = ['importance']).sort_values('importance', ascending=False)
#feature_importances
